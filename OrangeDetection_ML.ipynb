# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt

# %%
from google.colab import drive
import os

# Mount your Google Drive
drive.mount('/content/drive')

# Define the path where the yaml file will be saved in Google Drive
yaml_file_path = '/content/drive/MyDrive/oranges.yaml'

# Write the YAML content to the file
with open(yaml_file_path, 'w') as f:
    f.write('''train: /content/drive/MyDrive/images/train  # or the path where you stored the images
val: /content/drive/MyDrive/images/valid  # or the path where you stored the images

nc: 1  # number of classes
names: ['orange']  # list of class names
''')

print(f'YAML file created at {yaml_file_path}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# YAML file created at /content/drive/MyDrive/oranges.yaml

# %%
# !python train.py --img 640 --batch 16 --epochs 1 --data /content/drive/MyDrive/oranges.yaml --weights yolov5s.pt --cache --save-period 1 --project /content/drive/MyDrive/yolo_training --name custom_experiment
# Out:
# 2024-09-12 05:14:14.213397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-12 05:14:14.272783: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-12 05:14:14.290396: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 4 --data /content/drive/MyDrive/oranges.yaml --weights /content/drive/MyDrive/yolo_training/custom_experiment/weights/last.pt --cache --resume

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python detect.py --weights /content/drive/MyDrive/yolo_training/custom_experiment/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/images/test/images --project /content/drive/MyDrive/yolo_inference --name detection_results
# Out:
# detect: weights=['/content/drive/MyDrive/yolo_training/custom_experiment/weights/best.pt'], source=/content/drive/MyDrive/images/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/yolo_inference, name=detection_results, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-365-g12b577c8 Python-3.10.12 torch-2.4.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/202 /content/drive/MyDrive/images/test/images/000003_jpg.rf.366014fcecc2f47157a6e0064246e81a.jpg: 640x640 2 oranges, 387.7ms
# ...

# %%
# !ls /content/drive/MyDrive/images/test/images
# Out:
#  000003_jpg.rf.366014fcecc2f47157a6e0064246e81a.jpg
#  000005_jpg.rf.cb2f9f2f33b2643ee56881e3105313fc.jpg
#  000006_jpg.rf.0d930e50784dfdf7712c622f9f274d95.jpg
#  000013_jpg.rf.6df434b544d09fe0a65608b013d40c30.jpg
#  000043_jpg.rf.0e1cfd5ee9f276800d40c91c409d3262.jpg
#  000051_jpg.rf.7bbdc70998062aad26e3ae5278d031dc.jpg
#  000057_jpg.rf.b9fe7387eacbd7fbe45d308a2f821ad5.jpg
#  000062_jpg.rf.ccda41b2873eb37f46bc86a0d7fc69d9.jpg
#  000067_jpg.rf.e8e1953b5d063d66d8c7153ebd0a6398.jpg
#  000083_jpg.rf.e72a360e54c8fec71547423f09a06ee9.jpg
#  000084_jpg.rf.64d6578e1286b0cf50e8ce1b48553a85.jpg
#  000110_jpg.rf.f0b9623cca6a7ab06e7978f85301348d.jpg
#  000132_jpg.rf.9eaa0208a8af837a23eb63514a09a953.jpg
#  000206_jpg.rf.1ecedb9ee0f9823ea72d04b7e9b57757.jpg
#  000257_jpg.rf.c5a9da35a04ea1c40d3964f221028f81.jpg
#  000355_jpg.rf.a3ae2ceb8b6d435dbce61105937160aa.jpg
#  000392_jpg.rf.4da910de02cdc1bf1b4c59c0a3b73d63.jpg
#  000438_jpg.rf.e86fcba60e1cc0867c8bbc3f72ed5a12.jpg
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb37aacb-f558-447a-acc9-f3d7e2faf477" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb37aacb-f558-447a-acc9-f3d7e2faf477">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolo_training/custom_experiment/weights/best.pt --img 640 --conf 0.25 --source /content/image.jpg --project /content/drive/MyDrive/yolo_inference --name detection_results
# Out:
# detect: weights=['/content/drive/MyDrive/yolo_training/custom_experiment/weights/best.pt'], source=/content/image.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/drive/MyDrive/yolo_inference, name=detection_results, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-365-g12b577c8 Python-3.10.12 torch-2.4.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/image.jpg: 576x640 1 orange, 363.5ms
# Speed: 3.5ms pre-process, 363.5ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/drive/MyDrive/yolo_inference/detection_results6
